# %%
import pandas as pd
import xml.etree.ElementTree as ET
import io

def iter_docs(HealthData,rcd):
    pat_attr = HealthData.attrib
    for doc in HealthData.iter(rcd):
        doc_dict = pat_attr.copy()
        doc_dict.update(doc.attrib)
        doc_dict['data'] = doc.text
        yield doc_dict

etree = ET.parse('export_1.xml') #create an ElementTree object 
df_health = pd.DataFrame(list(iter_docs(etree.getroot(),'Record')))
df_patient = pd.DataFrame(list(iter_docs(etree.getroot(),'ClinicalRecord')))

# %%
df_health['patient'] = df_patient[df_patient['type']=='Patient']['resourceFilePath'].str.split('Patient-')[0][1][:-5]

# %%
df_health[df_health['type'] == 'HKQuantityTypeIdentifierBloodGlucose']
# Out:
#     locale                                  type         sourceName  \
# 0    en_US  HKQuantityTypeIdentifierBloodGlucose  HealthKitTestData
# 1    en_US  HKQuantityTypeIdentifierBloodGlucose  HealthKitTestData
# 2    en_US  HKQuantityTypeIdentifierBloodGlucose  HealthKitTestData
# 3    en_US  HKQuantityTypeIdentifierBloodGlucose  HealthKitTestData
# 4    en_US  HKQuantityTypeIdentifierBloodGlucose  HealthKitTestData
# ..     ...                                   ...                ...
# 247  en_US  HKQuantityTypeIdentifierBloodGlucose  HealthKitTestData
# 248  en_US  HKQuantityTypeIdentifierBloodGlucose  HealthKitTestData
# 249  en_US  HKQuantityTypeIdentifierBloodGlucose  HealthKitTestData
# 250  en_US  HKQuantityTypeIdentifierBloodGlucose  HealthKitTestData
# 251  en_US  HKQuantityTypeIdentifierBloodGlucose  HealthKitTestData
#
#     sourceVersion   unit               creationDate  \
# 0               1  mg/dL  2021-02-18 18:26:36 +0530
# 1               1  mg/dL  2021-02-18 18:26:37 +0530
# 2               1  mg/dL  2021-02-18 18:26:37 +0530
# 3               1  mg/dL  2021-02-18 18:26:37 +0530
# 4               1  mg/dL  2021-02-18 18:26:37 +0530
# ..            ...    ...                        ...
# 247             1  mg/dL  2021-02-23 20:10:31 +0530
# 248             1  mg/dL  2021-02-23 20:10:31 +0530
# 249             1  mg/dL  2021-02-23 20:10:32 +0530
# 250             1  mg/dL  2021-02-23 20:10:32 +0530
# 251             1  mg/dL  2021-02-23 20:10:33 +0530
#
#                      startDate                    endDate value  data  \
# 0    2021-01-29 18:26:36 +0530  2021-01-29 18:26:36 +0530  8600  None
# 1    2021-01-30 18:26:36 +0530  2021-01-30 18:26:36 +0530  5500  None
# 2    2021-01-31 18:26:36 +0530  2021-01-31 18:26:36 +0530   300  None
# 3    2021-02-01 18:26:36 +0530  2021-02-01 18:26:36 +0530  3900  None
# 4    2021-02-02 18:26:36 +0530  2021-02-02 18:26:36 +0530  4300  None
# ..                         ...                        ...   ...   ...
# 247  2021-02-19 20:10:26 +0530  2021-02-19 20:10:26 +0530  5800  None
# 248  2021-02-20 20:10:26 +0530  2021-02-20 20:10:26 +0530  7300  None
# 249  2021-02-21 20:10:26 +0530  2021-02-21 20:10:26 +0530  2200  None
# 250  2021-02-22 20:10:26 +0530  2021-02-22 20:10:26 +0530   300  None
# 251  2021-02-23 20:10:26 +0530  2021-02-23 20:10:26 +0530   400  None
#
#                                   patient
# 0    06ED19D5-F09D-44A2-B6CE-E7729E56C877
# 1    06ED19D5-F09D-44A2-B6CE-E7729E56C877
# 2    06ED19D5-F09D-44A2-B6CE-E7729E56C877
# 3    06ED19D5-F09D-44A2-B6CE-E7729E56C877
# 4    06ED19D5-F09D-44A2-B6CE-E7729E56C877
# ..                                    ...
# 247  06ED19D5-F09D-44A2-B6CE-E7729E56C877
# 248  06ED19D5-F09D-44A2-B6CE-E7729E56C877
# 249  06ED19D5-F09D-44A2-B6CE-E7729E56C877
# 250  06ED19D5-F09D-44A2-B6CE-E7729E56C877
# 251  06ED19D5-F09D-44A2-B6CE-E7729E56C877
#
# [252 rows x 11 columns]
